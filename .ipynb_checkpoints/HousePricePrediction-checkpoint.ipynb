# %% [markdown]
# # 1. Reading data

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn

# %%
trainDF = pd.read_csv('E:\\Work\\Notebooks\\HousePrices\\Data\\train.csv')
trainDF.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # 2. Taking columns that seem more important than others

# %%
subDf = trainDF[['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'LotShape', 'Utilities', 'OverallQual', 'OverallCond', 'ExterQual', 'ExterCond', 'HeatingQC', 'GarageQual', 'GarageCond', 'Fence', 'SaleCondition', 'SalePrice']]
subDf.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea LotShape Utilities  OverallQual  \
# 0          60       RL         65.0     8450      Reg    AllPub            7
# 1          20       RL         80.0     9600      Reg    AllPub            6
# 2          60       RL         68.0    11250      IR1    AllPub            7
# 3          70       RL         60.0     9550      IR1    AllPub            7
# 4          60       RL         84.0    14260      IR1    AllPub            8
#
#    OverallCond ExterQual ExterCond HeatingQC GarageQual GarageCond Fence  \
# 0            5        Gd        TA        Ex         TA         TA   NaN
# 1            8        TA        TA        Ex         TA         TA   NaN
# 2            5        Gd        TA        Ex         TA         TA   NaN
# 3            5        TA        TA        Gd         TA         TA   NaN
# 4            5        Gd        TA        Ex         TA         TA   NaN
#
#   SaleCondition  SalePrice
# 0        Normal     208500
# ...

# %% [markdown]
# # 3. Transforming categorical variables on a linear scale (For e.g. 1,2,3 etc)

# %%
MSZoningMap = {'A':1, 'FV':2, 'I': 3, 'C':4, 'RL':5, 'RP':6, 'RM':7, 'RH':8}
LotShapeMap = {'IR3':1, 'IR2':2, 'IR1': 3, 'Reg':4}
UtilMap = {'ELO':1, 'NoSeWa':2, 'NoSewr': 3, 'AllPub':4}
ExterQualMap = {'Po':1, 'Fa':2, 'TA': 3, 'Gd':4, 'Ex':5}
ExterCondMap = {'Po':1, 'Fa':2, 'TA': 3, 'Gd':4, 'Ex':5}
HeatingQCMap = {'Po':1, 'Fa':2, 'TA': 3, 'Gd':4, 'Ex':5}
GarageQualMap = {'Po':1, 'Fa':2, 'TA': 3, 'Gd':4, 'Ex':5}
GarageCondMap = {'Po':1, 'Fa':2, 'TA': 3, 'Gd':4, 'Ex':5}
FenceMap = {'NA':0, 'MnWw':1, 'GdWo': 2, 'MnPrv':3, 'GdPrv':4}
SaleConditionMap = {'Partial':1, 'Family':2, 'Alloca': 3, 'AdjLand':4, 'Abnorml':5, 'Normal':6}


for i, row in subDF.iterrows():
    subDF
